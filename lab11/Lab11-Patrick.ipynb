# %%
#Question 1
from networkx.algorithms.community.centrality import girvan_newman
from networkx.algorithms.community import greedy_modularity_communities
import networkx as nx
import itertools

vertices = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I']
es = [('A','B'), ('A','C'), ('B','C'), ('C','D'), ('B','H'), ('H','I'), ('H','G'), ('D','E'), ('D','F'), ('I','G'), ('G','E'), ('E','F')]

G = nx.Graph()

G.add_nodes_from(vertices)
G.add_edges_from(es)

com = list(girvan_newman(G))
nodes=[]
for c in com[1]:
    nodes.append(c)
print("The found communities are:")
print(nodes)
# Out:
# The found communities are:
# [{'A', 'B', 'C'}, {'E', 'D', 'F'}, {'H', 'G', 'I'}]

# %%
#Question 2

from collections import defaultdict
import community as community_louvain

vertices = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I']
es = [('A','B'), ('A','C'), ('B','C'), ('C','D'), ('B','H'), ('H','I'), ('H','G'), ('D','E'), ('D','F'), ('I','G'), ('G','E'), ('E','F')]

G = nx.Graph()

G.add_nodes_from(vertices)
G.add_edges_from(es)

part = community_louvain.best_partition(G)

nodes = defaultdict(list)
for key,  val in part.items():
    nodes[val].append(key)

nodes = list(nodes.values())
print(nodes)
color_map = []
for node in G:
    if node in nodes[0]:
        color_map.append('red')
    elif node in nodes[1]:
        color_map.append('blue')
    else:
        color_map.append('yellow')
nx.draw(G, node_color=color_map, with_labels=True)
# Out:
# [['A', 'B', 'C'], ['D', 'E', 'F'], ['G', 'H', 'I']]

# %%
#Question 3

from collections import defaultdict

vertices = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I']
es = [('A','B'), ('A','C'), ('B','C'), ('C','D'), ('B','H'), ('H','I'), ('H','G'), ('D','E'), ('D','F'), ('I','G'), ('G','E'), ('E','F')]

G = nx.Graph()

G.add_nodes_from(vertices)
G.add_edges_from(es)

part = greedy_modularity_communities(G)

nodes = []
for a in part:
    nodes.append(list(a))

print(nodes)
color_map = []
for node in G:
    if node in nodes[0]:
        color_map.append('red')
    elif node in nodes[1]:
        color_map.append('blue')
    else:
        color_map.append('yellow')
nx.draw(G, node_color=color_map, with_labels=True)
# Out:
# [['A', 'B', 'C'], ['E', 'D', 'F'], ['H', 'G', 'I']]
